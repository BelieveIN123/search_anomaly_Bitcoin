# %% [markdown]
# # prepare data

# %%
import pandas as pd
from datetime import timedelta

# %% [markdown]
# ### Пример данных

# %%
# Примерные входные данные (замените своими)
# df_investments: date, amount
df_investments = pd.DataFrame({
    'date': pd.date_range('2020-01-01', periods=36, freq='MS'),
    'amount': [150]*36
})

# df_rates: date, rate (где rate - годовая ставка, например 0.06 для 6%)
df_rates = pd.DataFrame({
    'date': pd.date_range('2020-01-01', periods=36, freq='MS'),
    'rate': [0.10, 0.10, 0.10] * 12
    #'rate': [0.06, 0.05, 0.07] * 12
})

# %%
df_investments
# Out:
#          date  amount
# 0  2020-01-01     150
# 1  2020-02-01     150
# 2  2020-03-01     150
# 3  2020-04-01     150
# 4  2020-05-01     150
# 5  2020-06-01     150
# 6  2020-07-01     150
# 7  2020-08-01     150
# 8  2020-09-01     150
# 9  2020-10-01     150
# 10 2020-11-01     150
# 11 2020-12-01     150
# 12 2021-01-01     150
# 13 2021-02-01     150
# 14 2021-03-01     150
# 15 2021-04-01     150
# 16 2021-05-01     150
# 17 2021-06-01     150
# 18 2021-07-01     150
# 19 2021-08-01     150
# 20 2021-09-01     150
# 21 2021-10-01     150
# 22 2021-11-01     150
# 23 2021-12-01     150
# 24 2022-01-01     150
# 25 2022-02-01     150
# 26 2022-03-01     150
# 27 2022-04-01     150
# 28 2022-05-01     150
# 29 2022-06-01     150
# 30 2022-07-01     150
# 31 2022-08-01     150
# 32 2022-09-01     150
# 33 2022-10-01     150
# 34 2022-11-01     150
# 35 2022-12-01     150

# %% [markdown]
# ### Чтение данных

# %%
df_investments.to_excel('investments.xlsx')

df_rates = pd.read_excel("Процентная ставка вклады 2010-2024.xlsx")
df_rates = df_rates.rename(columns={'Декада':'date', "Ставка, %":"rate"})

df_investments = pd.read_excel("Вклады.xlsx")


df_rates['rate'] = df_rates['rate'] * 0.01

# %% [markdown]
# ### Глобальные настройки.

# %%
# Параметры
n = 450  # минимальная сумма для открытия вклада
investment_duration = 12  # продолжительность вклада в месяцах

# Объединяем данные по датам
df = pd.merge(df_investments, df_rates, on='date', how='left')

# %%
if df.isna().sum().sum() != 0:
    raise ValueError("Есть пропуск. Проверить данные.")

# %% [markdown]
# # Обработка вкладов, первый собранные вклады.

# %%
# Рассчитаем доходность по вкладам
def calculate_income(df, min_sum, duration):
    total_income = []
    balance = 0  # текущий баланс для инвестирования
    start_dates = []

    for i, row in df.iterrows():
        balance += row['amount']
        if balance >= min_sum:
            # Открываем вклад
            start_date = row['date']
            end_date = start_date + pd.DateOffset(months=duration)
            deposit_rate = df[(df['date'] == start_date)]['rate'].mean()
            # deposit_rate = df[(df['date'] >= start_date) & (df['date'] < end_date)]['rate'].mean()
            print("deposit_rate", deposit_rate)
            
            if pd.notna(deposit_rate):
                income = balance * deposit_rate * (duration / 12)
                total_income.append({
                    'start_date': start_date,
                    'end_date': end_date,
                    'principal': balance,
                    'rate': deposit_rate,
                    'income': income
                })
            
            # Обнуляем баланс после открытия вклада
            balance = 0
    
    return pd.DataFrame(total_income)

# Вычисление доходности первичных вкладов
df_income = calculate_income(df, n, investment_duration)
print(df_income)
# Out:
# deposit_rate 0.09514
# deposit_rate 0.09561
# deposit_rate 0.09521000000000002
# deposit_rate 0.09538
# deposit_rate 0.0977
# deposit_rate 0.09736
# deposit_rate 0.09936
# deposit_rate 0.10625
# deposit_rate 0.10534
# deposit_rate 0.094
# deposit_rate 0.09460000000000002
# deposit_rate 0.0965
# deposit_rate 0.0965
# deposit_rate 0.09835
# deposit_rate 0.09975
# deposit_rate 0.0994
# deposit_rate 0.0969
# deposit_rate 0.09445
# deposit_rate 0.0926
# deposit_rate 0.09050000000000001
# deposit_rate 0.0889
# deposit_rate 0.08664999999999999
# deposit_rate 0.084
# deposit_rate 0.08449999999999999
# deposit_rate 0.08310000000000001
# deposit_rate 0.0827
# deposit_rate 0.08345000000000001
# deposit_rate 0.08615
# deposit_rate 0.08635
# deposit_rate 0.08835000000000001
# deposit_rate 0.09005
# deposit_rate 0.09145
# deposit_rate 0.09325
# deposit_rate 0.09502000000000001
# deposit_rate 0.09895
# deposit_rate 0.1058
# deposit_rate 0.15325
# deposit_rate 0.14705000000000001
# deposit_rate 0.1385
# deposit_rate 0.13175
# deposit_rate 0.12400000000000001
# deposit_rate 0.1159
# deposit_rate 0.11042
# deposit_rate 0.10414999999999999
# deposit_rate 0.10512
# deposit_rate 0.10352
# deposit_rate 0.09917
# deposit_rate 0.09899
# deposit_rate 0.09999000000000001
# deposit_rate 0.09759000000000001
# deposit_rate 0.09789
# deposit_rate 0.09648999999999999
# deposit_rate 0.09755000000000001
# deposit_rate 0.09425000000000001
# deposit_rate 0.0913
# deposit_rate 0.0883
# deposit_rate 0.08715
# deposit_rate 0.0866
# deposit_rate 0.08735
# deposit_rate 0.0849
# deposit_rate 0.084
# deposit_rate 0.08055
# deposit_rate 0.08045000000000001
# deposit_rate 0.07798000000000001
# deposit_rate 0.07918
# deposit_rate 0.07593
# deposit_rate 0.07363
# deposit_rate 0.0743
# deposit_rate 0.07348
# deposit_rate 0.07237
# deposit_rate 0.07395
# deposit_rate 0.0738
# deposit_rate 0.07245
# deposit_rate 0.06964000000000001
# deposit_rate 0.06659
# deposit_rate 0.064
# deposit_rate 0.0637
# deposit_rate 0.06052
# deposit_rate 0.06394
# deposit_rate 0.06319
# deposit_rate 0.06613000000000001
# deposit_rate 0.06798
# deposit_rate 0.07179
# deposit_rate 0.07382
# deposit_rate 0.07529
# deposit_rate 0.07495
# deposit_rate 0.07675
# deposit_rate 0.07535
# deposit_rate 0.07522000000000001
# deposit_rate 0.07306
# deposit_rate 0.07135
# deposit_rate 0.06823
# deposit_rate 0.06714
# deposit_rate 0.06478
# deposit_rate 0.061689999999999995
# deposit_rate 0.06126
# deposit_rate 0.059269999999999996
# deposit_rate 0.05489
# deposit_rate 0.051500000000000004
# deposit_rate 0.05427
# deposit_rate 0.055080000000000004
# deposit_rate 0.050140000000000004
# deposit_rate 0.04629
# deposit_rate 0.045149999999999996
# deposit_rate 0.044059999999999995
# deposit_rate 0.04326
# deposit_rate 0.04419
# deposit_rate 0.04456
# deposit_rate 0.04486
# deposit_rate 0.044660000000000005
# deposit_rate 0.04529
# deposit_rate 0.046340000000000006
# deposit_rate 0.04934
# deposit_rate 0.05103
# deposit_rate 0.053
# deposit_rate 0.05749
# deposit_rate 0.061529999999999994
# deposit_rate 0.06433
# deposit_rate 0.06984
# deposit_rate 0.07379
# deposit_rate 0.07738
# deposit_rate 0.07801999999999999
# deposit_rate 0.20510000000000003
# deposit_rate 0.16579999999999998
# deposit_rate 0.12095000000000002
# deposit_rate 0.0909
# deposit_rate 0.07645
# deposit_rate 0.06825
# deposit_rate 0.06835000000000001
# deposit_rate 0.06669
# deposit_rate 0.06984
# deposit_rate 0.07392
# deposit_rate 0.08130000000000001
# deposit_rate 0.07926
# deposit_rate 0.07676000000000001
# deposit_rate 0.07676000000000001
# deposit_rate 0.07636
# deposit_rate 0.07827
# deposit_rate 0.07827
# deposit_rate 0.08146
# deposit_rate 0.09696
# deposit_rate 0.1018
# deposit_rate 0.13567
# deposit_rate 0.14003000000000002
# deposit_rate 0.14793
# deposit_rate 0.14830000000000002
# deposit_rate 0.14847
# deposit_rate 0.14832
# deposit_rate 0.14952000000000001
# deposit_rate 0.15688000000000002
# deposit_rate 0.16574000000000003
# deposit_rate 0.17275
# deposit_rate 0.17633
# deposit_rate 0.1978
# deposit_rate 0.20905
#     start_date   end_date  principal     rate   income
# 0   2012-01-01 2013-01-01     100000  0.09514  9514.00
# 1   2012-02-01 2013-02-01      15000  0.09561  1434.15
# 2   2012-03-01 2013-03-01      15000  0.09521  1428.15
# 3   2012-04-01 2013-04-01      15000  0.09538  1430.70
# 4   2012-05-01 2013-05-01      15000  0.09770  1465.50
# ..         ...        ...        ...      ...      ...
# 150 2024-07-01 2025-07-01      15000  0.16574  2486.10
# 151 2024-08-01 2025-08-01      15000  0.17275  2591.25
# 152 2024-09-01 2025-09-01      15000  0.17633  2644.95
# 153 2024-10-01 2025-10-01      15000  0.19780  2967.00
# 154 2024-11-01 2025-11-01      15000  0.20905  3135.75
#
# [155 rows x 5 columns]

# %%
max_date = df['date'].max() + pd.DateOffset(months=1)
max_date
# Out:
# Timestamp('2024-12-01 00:00:00')

# %%
from dateutil.relativedelta import relativedelta
from datetime import datetime

# Обработка первичных вкладов.
# Убираю периоды "будущей доходности".
# max_date = df['date'].max()
correct_income = []
for i, row in df_income.iterrows():
    if max_date < row["end_date"]:
        # n_month = relativedelta(max_date, )
        n_month = (max_date.year - row["start_date"].year) * 12 + (max_date.month - row["start_date"].month)
        row["income"] = n_month / 12 * row["income"]
        row["end_date"] = max_date
        
        correct_income.append(row)
    else:
        correct_income.append(row)

# %%
max_date, row["end_date"]
# Out:
# (Timestamp('2024-12-01 00:00:00'), Timestamp('2024-12-01 00:00:00'))

# %%
df_income_correct = pd.DataFrame(correct_income)

# %%
df_income_correct
# Out:
#     start_date   end_date  principal     rate     income
# 0   2012-01-01 2013-01-01     100000  0.09514  9514.0000
# 1   2012-02-01 2013-02-01      15000  0.09561  1434.1500
# 2   2012-03-01 2013-03-01      15000  0.09521  1428.1500
# 3   2012-04-01 2013-04-01      15000  0.09538  1430.7000
# 4   2012-05-01 2013-05-01      15000  0.09770  1465.5000
# ..         ...        ...        ...      ...        ...
# 150 2024-07-01 2024-12-01      15000  0.16574  1035.8750
# 151 2024-08-01 2024-12-01      15000  0.17275   863.7500
# 152 2024-09-01 2024-12-01      15000  0.17633   661.2375
# 153 2024-10-01 2024-12-01      15000  0.19780   494.5000
# 154 2024-11-01 2024-12-01      15000  0.20905   261.3125
#
# [155 rows x 5 columns]

# %% [markdown]
# # Расчёт повторных инвестиций.

# %%
income_new_all = []
for i, row in df_income_correct.iterrows():
    #row["end_date"]
    income_all_reinvest = []
    end_date_iter = row['end_date']
    total_money = row["principal"] + row["income"]
    while True:
        if end_date_iter < max_date:
            n_month_for_end = (max_date.year - end_date_iter.year) * 12 + (max_date.month - end_date_iter.month)
            n_month_deposit = min([12, n_month_for_end]) # Сколько месяцев вклада произошло.
            rate_in_date = df_rates.loc[df_rates.date == end_date_iter, "rate"].mean()
            new_income = (rate_in_date * total_money) * (n_month_deposit / 12)
            
            total_money += new_income
            end_date_iter = end_date_iter + pd.DateOffset(months=12)
            income_all_reinvest.append(new_income)
        else:
            break    
    
    income_new_all.append(income_all_reinvest)
    # break

# %%
df_income_new_all = pd.DataFrame(income_new_all)

# %%
i = 2
for col in list(df_income_new_all):
     col_name = "income_" + str(i)
     i += 1
     df_income_correct[col_name] = df_income_new_all[col]

# %%
df_income_correct[['principal', 'income', 'income_2', 'income_3']].sum().sum()
# Out:
# 3004396.206269422

# %%
df_income_correct
# Out:
#     start_date   end_date  principal     rate     income      income_2  \
# 0   2012-01-01 2013-01-01     100000  0.09514  9514.0000  10568.101000
# 1   2012-02-01 2013-02-01      15000  0.09561  1434.1500   1616.298653
# 2   2012-03-01 2013-03-01      15000  0.09521  1428.1500   1638.707963
# 3   2012-04-01 2013-04-01      15000  0.09538  1430.7000   1633.211580
# 4   2012-05-01 2013-05-01      15000  0.09770  1465.5000   1595.506950
# ..         ...        ...        ...      ...        ...           ...
# 150 2024-07-01 2024-12-01      15000  0.16574  1035.8750           NaN
# 151 2024-08-01 2024-12-01      15000  0.17275   863.7500           NaN
# 152 2024-09-01 2024-12-01      15000  0.17633   661.2375           NaN
# 153 2024-10-01 2024-12-01      15000  0.19780   494.5000           NaN
# 154 2024-11-01 2024-12-01      15000  0.20905   261.3125           NaN
#
#         income_3      income_4      income_5      income_6      income_7  \
# 0    9978.822593  19931.836541  14997.776086  13859.205042  12957.663754
# 1    1492.772104   2873.830612   2187.680043   1981.911115   1851.493786
# 2    1507.679297   2711.073410   2181.538428   1968.382145   1760.342025
# 3    1556.205983   2584.950489   2142.567016   1898.628583   1679.760874
# 4    1559.567950   2432.951288   2151.321480   1916.539838   1663.932384
# ..           ...           ...           ...           ...           ...
# 150          NaN           NaN           NaN           NaN           NaN
# 151          NaN           NaN           NaN           NaN           NaN
# 152          NaN           NaN           NaN           NaN           NaN
# 153          NaN           NaN           NaN           NaN           NaN
# 154          NaN           NaN           NaN           NaN           NaN
#
#          income_8      income_9    income_10     income_11     income_12  \
# 0    14441.179524  12224.353606  9800.696005  17663.813811  19994.714519
# 1     2131.438317   1677.963951  1440.175073   2628.315419   2878.408464
# 2     2164.033273   1563.535187  1445.812676   6844.034078   3086.772024
# 3     2104.225948   1629.741693  1467.124037   5492.475866   2964.439887
# 4     2090.011762   1645.533267  1555.239475   4000.554827   2831.173698
# ..            ...           ...          ...           ...           ...
# 150           NaN           NaN          NaN           NaN           NaN
# 151           NaN           NaN          NaN           NaN           NaN
# 152           NaN           NaN          NaN           NaN           NaN
# 153           NaN           NaN          NaN           NaN           NaN
# 154           NaN           NaN          NaN           NaN           NaN
#
#         income_13
# 0    36061.066063
# 1     4843.779239
# 2     4821.569988
# 3     4111.829080
# 4     3480.761187
# ..            ...
# 150           NaN
# 151           NaN
# 152           NaN
# 153           NaN
# 154           NaN
#
# [155 rows x 17 columns]

# %%
print(df_income_correct['principal'].sum(), df_investments['amount'].sum())
df_income_correct
# Out:
# 2410000 2410000
#     start_date   end_date  principal     rate     income      income_2  \
# 0   2012-01-01 2013-01-01     100000  0.09514  9514.0000  10568.101000
# 1   2012-02-01 2013-02-01      15000  0.09561  1434.1500   1616.298653
# 2   2012-03-01 2013-03-01      15000  0.09521  1428.1500   1638.707963
# 3   2012-04-01 2013-04-01      15000  0.09538  1430.7000   1633.211580
# 4   2012-05-01 2013-05-01      15000  0.09770  1465.5000   1595.506950
# ..         ...        ...        ...      ...        ...           ...
# 150 2024-07-01 2024-12-01      15000  0.16574  1035.8750           NaN
# 151 2024-08-01 2024-12-01      15000  0.17275   863.7500           NaN
# 152 2024-09-01 2024-12-01      15000  0.17633   661.2375           NaN
# 153 2024-10-01 2024-12-01      15000  0.19780   494.5000           NaN
# 154 2024-11-01 2024-12-01      15000  0.20905   261.3125           NaN
#
#         income_3      income_4      income_5      income_6      income_7  \
# 0    9978.822593  19931.836541  14997.776086  13859.205042  12957.663754
# 1    1492.772104   2873.830612   2187.680043   1981.911115   1851.493786
# 2    1507.679297   2711.073410   2181.538428   1968.382145   1760.342025
# 3    1556.205983   2584.950489   2142.567016   1898.628583   1679.760874
# 4    1559.567950   2432.951288   2151.321480   1916.539838   1663.932384
# ..           ...           ...           ...           ...           ...
# 150          NaN           NaN           NaN           NaN           NaN
# 151          NaN           NaN           NaN           NaN           NaN
# 152          NaN           NaN           NaN           NaN           NaN
# 153          NaN           NaN           NaN           NaN           NaN
# 154          NaN           NaN           NaN           NaN           NaN
#
#          income_8      income_9    income_10     income_11     income_12  \
# 0    14441.179524  12224.353606  9800.696005  17663.813811  19994.714519
# 1     2131.438317   1677.963951  1440.175073   2628.315419   2878.408464
# 2     2164.033273   1563.535187  1445.812676   6844.034078   3086.772024
# 3     2104.225948   1629.741693  1467.124037   5492.475866   2964.439887
# 4     2090.011762   1645.533267  1555.239475   4000.554827   2831.173698
# ..            ...           ...          ...           ...           ...
# 150           NaN           NaN          NaN           NaN           NaN
# 151           NaN           NaN          NaN           NaN           NaN
# 152           NaN           NaN          NaN           NaN           NaN
# 153           NaN           NaN          NaN           NaN           NaN
# 154           NaN           NaN          NaN           NaN           NaN
#
#         income_13
# 0    36061.066063
# 1     4843.779239
# 2     4821.569988
# 3     4111.829080
# 4     3480.761187
# ..            ...
# 150           NaN
# 151           NaN
# 152           NaN
# 153           NaN
# 154           NaN
#
# [155 rows x 17 columns]

# %%
df_income_correct.to_excel("Итоги прибылей.xlsx")

# %%
df_income[["principal", "income"]].sum().sum()
# Out:
# 2625371.75

# %%
df_investments['amount'].sum()

# %%
# Ошибки
# Сумма вкладов. 
# Исправить дату окончания.
